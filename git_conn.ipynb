# %% [markdown]
# Creating git connection

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive/Georgia Tech/Machine Learning-CS7641/Assignments/Git'
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Georgia Tech/Machine Learning-CS7641/Assignments/Git

# %%
# Initialize local git folder
! git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Georgia Tech/Machine Learning-CS7641/Assignments/Git/.git/

# %%
# Tell git about yourself
! git config --global user.email 'saghigh3@gatech.edu'
! git config --global user.name 'saghigh3'

# %%
! git status

# %%
# Adding git ignore file
! touch .gitignore

# %%
ls
# Out:
#  git_conn.ipynb  'Project #1'/  'Project #2'/  'Project #3'/  'Project #4'/

# %%
# Adding files to be ignored by Git
! echo "Project #1/ReadMe.docx" >> .gitignore

# %%
! echo "Project #2/README.docx" >> .gitignore

# %%
! echo "Project #2/mlrose" >> .gitignore

# %%
! echo "Project #3/ReadMe.docx" >> .gitignore

# %%
! echo "Project #4/ReadMe.docx" >> .gitignore

# %%
! echo "Project #4/hiivemdptoolbox" >> .gitignore

# %%
! git add .gitignore

# %%
# Adding specefied folder
! git add 'Project #3'

# %%
# Commiting changes with comment
! git commit -m 'Adding Project 3'
# Out:
# [master 2ed41b9] Adding Project 3
#  2 files changed, 0 insertions(+), 0 deletions(-)
#  delete mode 100644 Project #2/saghigh3@gatech.edu-analysis #2.pdf
#  delete mode 100644 Project #3/Saghigh3@gatech.edu-analysis #3.pdf

# %%
token = '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'
repository = 'Machine_Learning'
username = 'saghigh3'

# %%
! git remote rm origin

# %%
# !git remote add origin https://{username}:{token}@github.com/{username}/{repository}.git

# %%
# !git push -u origin master
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 354 bytes | 50.00 KiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/saghigh3/Machine_Learning.git
#    92aaeb2..2ed41b9  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# Removing a file from git while keeping it in local drive (Use -rf to recursively force delete files within a forlder)
! git rm --cached "Project #1/ReadMe.docx"
# Out:
# rm 'Project #1/ReadMe.docx'

# %%
! git rm -rf --cached "Project #2/mlrose"
# Out:
# rm 'Project #2/mlrose/LICENSE'
# rm 'Project #2/mlrose/README.md'
# rm 'Project #2/mlrose/docs/Makefile'
# rm 'Project #2/mlrose/docs/conf.py'
# rm 'Project #2/mlrose/docs/index.rst'
# rm 'Project #2/mlrose/docs/make.bat'
# rm 'Project #2/mlrose/docs/requirements.txt'
# rm 'Project #2/mlrose/docs/source/algorithms.rst'
# rm 'Project #2/mlrose/docs/source/decay.rst'
# rm 'Project #2/mlrose/docs/source/fitness.rst'
# rm 'Project #2/mlrose/docs/source/intro.rst'
# rm 'Project #2/mlrose/docs/source/neural.rst'
# rm 'Project #2/mlrose/docs/source/opt_probs.rst'
# rm 'Project #2/mlrose/docs/source/pictures/chess1.JPG'
# rm 'Project #2/mlrose/docs/source/pictures/chess2.JPG'
# rm 'Project #2/mlrose/docs/source/pictures/chess3.JPG'
# rm 'Project #2/mlrose/docs/source/pictures/tsp1.jpg'
# rm 'Project #2/mlrose/docs/source/pictures/tsp2.jpg'
# rm 'Project #2/mlrose/docs/source/pictures/tsp3.jpg'
# rm 'Project #2/mlrose/docs/source/pictures/tsp4.jpg'
# ...

# %%
! git rm --cached "Project #3/Saghigh3@gatech.edu-analysis #3.pdf"
# Out:
# rm 'Project #3/Saghigh3@gatech.edu-analysis #3.pdf'

# %%
! git rm --cached "Project #2/saghigh3@gatech.edu-analysis #2.pdf"
# Out:
# rm 'Project #2/saghigh3@gatech.edu-analysis #2.pdf'

# %%
# Removing local git repository
! rm -fr .git

# %%
! git add .

# %%
! git commit -m "Adding Project Report"
# Out:
# [master bbbb468] Adding Project Report
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git_conn.ipynb (95%)

# %%
! git pull origin master
# Out:
# From https://github.com/saghigh3/Machine_Learning
#  * branch            master     -> FETCH_HEAD
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# fatal: Need to specify how to reconcile divergent branches.

# %%
! git pull origin master --rebase
# Out:
# error: cannot pull with rebase: You have unstaged changes.
# error: please commit or stash them.

# %%
! git push origin master
# Out:
# To https://github.com/saghigh3/Machine_Learning.git
#  ! [rejected]        master -> master (non-fast-forward)
# error: failed to push some refs to 'https://github.com/saghigh3/Machine_Learning.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
